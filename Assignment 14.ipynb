# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv")
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv")
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 327.4+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df.index = [np.arange(len(df.index)),df.index]
#df=pd.read_csv("https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv",index= np.arange(len))
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-124-94bd43051d62> in <module>()
# ----> 1 df.index = [np.arange(len(df.index)),df.index]
#       2 #df=pd.read_csv("https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv",index= np.arange(len))
#       3 df.head(2)
#
# c:\users\vyass\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\users\vyass\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
# ...

# %%
df1.index= [np.arange(len(df1.index)),df1.index]
df1.head(2)
# Out:
#                STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#      TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#      WT18  WT03
# 0 0 -9999 -9999
# 1 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df.rename(columns={'Indicator':'Indicator_id'}).head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.rename(columns={'Indicator':'Indicator_id'},inplace=True)
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.rename(columns={'Indicator':'Indicator_id','WHO region':'WHO Region'}).head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO Region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.sort_values(by=['Year'],ascending=[True]).head(2)
# Out:
#                           Indicator_id PUBLISH STATES  Year WHO region  \
# 0     Life expectancy at birth (years)      Published  1990     Europe
# 1270  Life expectancy at birth (years)      Published  1990     Europe
#
#      World Bank income group  Country         Sex  Display Value  Numeric  \
# 0                High-income  Andorra  Both sexes             77     77.0
# 1270             High-income  Germany        Male             72     72.0
#
#       Low  High  Comments
# 0     NaN   NaN       NaN
# 1270  NaN   NaN       NaN

# %%
df.sort_values(by=['Year','Country','WHO region','PUBLISH STATES','Indicator_id'],ascending=[True,True,True,True,True]).head(5)
# Out:
#                            Indicator_id PUBLISH STATES  Year  \
# 555   Life expectancy at age 60 (years)      Published  1990
# 1395  Life expectancy at age 60 (years)      Published  1990
# 2959  Life expectancy at age 60 (years)      Published  1990
# 554    Life expectancy at birth (years)      Published  1990
# 965    Life expectancy at birth (years)      Published  1990
#
#                  WHO region World Bank income group      Country         Sex  \
# 555   Eastern Mediterranean              Low-income  Afghanistan      Female
# 1395  Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 2959  Eastern Mediterranean              Low-income  Afghanistan        Male
# 554   Eastern Mediterranean              Low-income  Afghanistan  Both sexes
# 965   Eastern Mediterranean              Low-income  Afghanistan        Male
#
#       Display Value  Numeric  Low  High  Comments
# 555              15     15.0  NaN   NaN       NaN
# ...

# %%
df2=df.set_index('Country',drop=False)
df2.head(2)
# Out:
#          Country                      Indicator_id PUBLISH STATES  Year  \
# Country
# Andorra  Andorra  Life expectancy at birth (years)      Published  1990
# Andorra  Andorra  Life expectancy at birth (years)      Published  2000
#
#         WHO region World Bank income group         Sex  Display Value  \
# Country
# Andorra     Europe             High-income  Both sexes             77
# Andorra     Europe             High-income  Both sexes             80
#
#          Numeric  Low  High  Comments
# Country
# Andorra     77.0  NaN   NaN       NaN
# Andorra     80.0  NaN   NaN       NaN

# %%
df.columns
# Out:
# Index(['Country', 'Indicator_id', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Sex', 'Display Value', 'Numeric', 'Low',
#        'High', 'Comments'],
#       dtype='object')

# %%
df.index = [np.arange(len(df.index)), df.index]
df.head(15)
#df.loc[11,24,37]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-68-8dcb1df279de> in <module>()
# ----> 1 df.index = [np.arange(len(df.index)), df.index]
#       2 df.head(15)
#       3 #df.loc[11,24,37]
#
# c:\users\vyass\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\users\vyass\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
# ...

# %%
df.drop(5,12,23,56)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-33f64283a2ea> in <module>()
# ----> 1 df.drop(5,12,23,56)
#
# c:\users\vyass\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2514         if labels is not None:
#    2515             if index is not None or columns is not None:
# -> 2516                 raise ValueError("Cannot specify both 'labels' and "
#    2517                                  "'index'/'columns'")
#    2518             axis_name = self._get_axis_name(axis)
#
# ValueError: Cannot specify both 'labels' and 'index'/'columns'

# %%
User=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv")
User.head(2)
# Out:
#    UserID     User Gender  Registered   Cancelled
# 0       1  Charles   male  2012-12-21         NaN
# 1       2    Pedro   male  2010-08-01  2010-08-08

# %%
session=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv")
session.head(2)
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2

# %%
Product=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv")
Product.head(2)
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04

# %%
Transx=pd.read_csv("https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv")
Transx.head(2)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1

# %%
df4=pd.merge(Transx,User, on= 'UserID', how="left")
df4.head()
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21      7          2         1       NaN
# 1              2      2011-05-26      3          4         1  Caroline
# 2              3      2011-06-16      3          3         1  Caroline
# 3              4      2012-08-26      1          2         3   Charles
# 4              5      2013-06-06      2          4         1     Pedro
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08

# %%
df5=pd.merge(Transx,User, on= 'UserID', how="inner")
df5.head()
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26      3          4         1  Caroline
# 1              3      2011-06-16      3          3         1  Caroline
# 2              7      2013-12-30      3          4         1  Caroline
# 3             10      2016-05-08      3          4         4  Caroline
# 4              4      2012-08-26      1          2         3   Charles
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN

# %%
df6=pd.merge(Transx,User, on= 'UserID', how="outer")
df6.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0            1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1            9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2            2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3            3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4            7.0      2013-12-30     3.0        4.0       1.0  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1     NaN         NaN         NaN
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4  female  2012-10-23  2016-06-07

# %%
df7=pd.merge(User,session, how='inner', left_on=['UserID', 'Registered'], right_on=['UserID', 'SessionDate'])
df7
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %%
df8=pd.merge(User,session, on= 'UserID', how="inner")
df8.head(2)
# Out:
#    UserID   User Gender  Registered   Cancelled  SessionID SessionDate
# 0       2  Pedro   male  2010-08-01  2010-08-08          1  2010-01-05
# 1       2  Pedro   male  2010-08-01  2010-08-08          2  2010-08-01

# %%
df10=pd.merge(Transx, Transx, on='UserID')
df10.head()
# Out:
#    TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                1        2010-08-21     7.0            2           1
# 1                1        2010-08-21     7.0            2           1
# 2                9        2015-04-24     7.0            4           3
# 3                9        2015-04-24     7.0            4           3
# 4                2        2011-05-26     3.0            4           1
#
#    TransactionID_y TransactionDate_y  ProductID_y  Quantity_y
# 0                1        2010-08-21            2           1
# 1                9        2015-04-24            4           3
# 2                1        2010-08-21            2           1
# 3                9        2015-04-24            4           3
# 4                2        2011-05-26            4           1

# %%
df12=pd.merge(User,Transx,on='UserID',how='inner')
df12.head(2)
# Out:
#   UserID     User Gender  Registered   Cancelled  Key  TransactionID  \
# 0      1  Charles   male  2012-12-21         NaN    1              4
# 1      2    Pedro   male  2010-08-01  2010-08-08    1              5
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26          2         3
# 1      2013-06-06          4         1
